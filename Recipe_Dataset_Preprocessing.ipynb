# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

# %%
# Load Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Minor Project - Semester 7/Datasets/recipes.csv"

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    RecipeId                               Name  AuthorId      AuthorName  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533          Dancer
# 1        39                            Biryani      1567        elly9812
# 2        40                      Best Lemonade      1566  Stephen Little
# 3        41     Carina's Tofu-Vegetable Kebabs      1586         Cyclopz
# 4        42                       Cabbage Soup      1538       Duckie067
#
#   CookTime PrepTime TotalTime         DatePublished  \
# 0    PT24H    PT45M  PT24H45M  1999-08-09T21:46:00Z
# 1    PT25M     PT4H   PT4H25M  1999-08-29T13:12:00Z
# 2     PT5M    PT30M     PT35M  1999-09-05T19:52:00Z
# 3    PT20M    PT24H  PT24H20M  1999-09-03T14:54:00Z
# 4    PT30M    PT20M     PT50M  1999-09-19T06:19:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
# 1  Make and share this Biryani recipe from Food.com.
# ...

# %%
# Dataset Analysis

# %%
df.columns
# Out:
# Index(['RecipeId', 'Name', 'AuthorId', 'AuthorName', 'CookTime', 'PrepTime',
#        'TotalTime', 'DatePublished', 'Description', 'Images', 'RecipeCategory',
#        'Keywords', 'RecipeIngredientQuantities', 'RecipeIngredientParts',
#        'AggregatedRating', 'ReviewCount', 'Calories', 'FatContent',
#        'SaturatedFatContent', 'CholesterolContent', 'SodiumContent',
#        'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent',
#        'RecipeServings', 'RecipeYield', 'RecipeInstructions'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(1)
# Out:
#    RecipeId                               Name  AuthorId AuthorName CookTime  \
# 0        38  Low-Fat Berry Blue Frozen Dessert      1533     Dancer    PT24H
#
#   PrepTime TotalTime         DatePublished  \
# 0    PT45M  PT24H45M  1999-08-09T21:46:00Z
#
#                                          Description  \
# 0  Make and share this Low-Fat Berry Blue Frozen ...
#
#                                               Images   RecipeCategory  \
# 0  c("https://img.sndimg.com/food/image/upload/w_...  Frozen Desserts
#
#                                             Keywords  \
# 0  c("Dessert", "Low Protein", "Low Cholesterol",...
#
#   RecipeIngredientQuantities  \
# 0    c("4", "1/4", "1", "1")
#
#                                RecipeIngredientParts  AggregatedRating  \
# 0  c("blueberries", "granulated sugar", "vanilla ...               4.5
#
#    ReviewCount  Calories  FatContent  SaturatedFatContent  CholesterolContent  \
# ...

# %%
df.shape
# Out:
# (522517, 28)

# %%
# Extract required columns

# %%
req_df = df[['Name', 'Calories', 'FatContent', 'SaturatedFatContent', 'CholesterolContent', 'SodiumContent', 'CarbohydrateContent', 'FiberContent', 'SugarContent', 'ProteinContent']]

# %%
req_df.head(1)
# Out:
#                                 Name  Calories  FatContent  \
# 0  Low-Fat Berry Blue Frozen Dessert     170.9         2.5
#
#    SaturatedFatContent  CholesterolContent  SodiumContent  \
# 0                  1.3                 8.0           29.8
#
#    CarbohydrateContent  FiberContent  SugarContent  ProteinContent
# 0                 37.1           3.6          30.2             3.2

# %%
req_df.describe()
# Out:
#             Calories     FatContent  SaturatedFatContent  CholesterolContent  \
# count  522517.000000  522517.000000        522517.000000       522517.000000
# mean      484.438580      24.614922             9.559457           86.487003
# std      1397.116649     111.485798            46.622621          301.987009
# min         0.000000       0.000000             0.000000            0.000000
# 25%       174.200000       5.600000             1.500000            3.800000
# 50%       317.100000      13.800000             4.700000           42.600000
# 75%       529.100000      27.400000            10.800000          107.900000
# max    612854.600000   64368.100000         26740.600000       130456.400000
#
#        SodiumContent  CarbohydrateContent   FiberContent   SugarContent  \
# count   5.225170e+05        522517.000000  522517.000000  522517.000000
# mean    7.672639e+02            49.089092       3.843242      21.878254
# ...

# %%
req_df.isnull().sum()
# Out:
# Name                   0
# Calories               0
# FatContent             0
# SaturatedFatContent    0
# CholesterolContent     0
# SodiumContent          0
# CarbohydrateContent    0
# FiberContent           0
# SugarContent           0
# ProteinContent         0
# dtype: int64

# %%
# Scaling the values

# %%
from sklearn.preprocessing import StandardScaler

scaled_df = req_df.copy()
scaler = StandardScaler()
scaled_df.iloc[:, 1:] = scaler.fit_transform(scaled_df.iloc[:, 1:])

# %%
scaled_df.head(10)
# Out:
#                                          Name  Calories  FatContent  \
# 0           Low-Fat Berry Blue Frozen Dessert -0.224419   -0.198366
# 1                                     Biryani  0.448253    0.306632
# 2                               Best Lemonade -0.124069   -0.218996
# 3              Carina's Tofu-Vegetable Kebabs  0.036977   -0.005516
# 4                                Cabbage Soup -0.272589   -0.217202
# 5                        Best Blackbottom Pie -0.033310   -0.047674
# 6                      Warm Chicken A La King  0.294222    0.378390
# 7  Buttermilk Pie With Gingersnap Crumb Crust -0.183549   -0.157105
# 8                     A Jad - Cucumber Pickle -0.343664   -0.220790
# 9                        Butter Pecan Cookies -0.297355   -0.170559
#
#    SaturatedFatContent  CholesterolContent  SodiumContent  \
# 0            -0.177156           -0.259902      -0.175436
# 1             0.151011            0.948098      -0.094886
# ...

# %%
# Save scaled dataframe to csv file

# %%
scaled_df.to_csv('recipes_processed.csv', index = False)
